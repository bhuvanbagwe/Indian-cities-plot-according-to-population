# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import image
from matplotlib import patches
from matplotlib import cbook
import numpy as np
import geopandas as gpd

# %%
# CSV Location
df =pd.read_csv('C:/Users/BHUVAN/Desktop/Satellite Image Processing/India/City Population mapping/Indian cities according to population.csv', header =None, nrows=1600,low_memory=False)
df.head()
# Out:
#           0          1        2        3      4   5    6            7      8   \
# 0      Delhi      Delhi  28.6667  77.2167  India  IN  IND        Delhi  admin
# 1     Mumbai     Mumbai  19.0758  72.8775  India  IN  IND  Mahārāshtra  admin
# 2    Kolkāta    Kolkata  22.5727  88.3639  India  IN  IND  West Bengal  admin
# 3  Bangalore  Bangalore  12.9791  77.5913  India  IN  IND    Karnātaka  admin
# 4    Chennai    Chennai  13.0825  80.2750  India  IN  IND   Tamil Nādu  admin
#
#          9           10          11
# 0  31870000  1356872604  100.000000
# 1  22186000  1356226629   69.614057
# 2  18698000  1356060520   58.669595
# 3  13999000  1356410365   43.925322
# 4  11564000  1356374944   36.284907

# %%
# Defining data columns

latitude = df[2]
longitude = df[3]
population = df[10]
city = df[1]

# %%
fig = plt.figure(figsize=(100,100))

countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
countries[countries["name"] == "India"].plot(color="lightgrey")

plt.scatter(longitude,latitude,c=population,cmap="tab20b",s=2.5)
plt.colorbar(label=" According to Population ", orientation="vertical") 
plt.savefig('C:/Users/BHUVAN/Desktop/Satellite Image Processing/India/City Population mapping/Indian Mapped according to city population.png', dpi=1000)
plt.show()
